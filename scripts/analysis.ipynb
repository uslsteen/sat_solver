# %%
import matplotlib.pyplot as plt
import numpy as np


impls = ("Run time", "Compile time", "Hybrid")
time_values = {
    'sat, N=70': (0.001, 2.27, 0.001),
    'sat, N=100': (0.373, 0, 0.218),
    'sat, N=125': (23.310, 0, 14.957),
    'sat, N=150': (37.839, 0, 25.5581),
}

x = np.arange(len(impls))
width = 0.25 
multiplier = 0

fig, ax = plt.subplots(figsize=(12, 8), layout='constrained')

for attribute, measurement in time_values.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, 0.2, label=attribute)
    ax.bar_label(rects, padding=5)
    multiplier += 1


ax.set_ylabel('Time (secs)')
ax.set_title('Perfomance of implementations')
ax.set_xticks(x + width, species)
ax.legend(loc='upper right', ncols=4)
ax.set_ylim(0, 50)

plt.show()
plt.show()
