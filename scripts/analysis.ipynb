# %%
import matplotlib.pyplot as plt
import numpy as np


impls = ("Run time", "Compile time", "Hybrid")
time_values = {
    '3-SAT, N=70': (0.001, 2.27, 0.001),
    '3-SAT, N=100': (1.43, 0, 0.76),
    '3-SAT, N=110': (1.65, 0, 1.21),
    '3-SAT, N=125': (33.13, 0, 28.00),
    '3-SAT, N=150': (50.30, 0, 42.57),
}

x = np.arange(len(impls))
width = 0.15
multiplier = 0

fig, ax = plt.subplots(figsize=(12, 8), layout='constrained')

for attribute, measurement in time_values.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=6)
    multiplier += 1


ax.set_ylabel('Time (secs)')
ax.set_title('Perfomance of implementations')
ax.set_xticks(x + width, species)
ax.legend(loc='upper right', ncols=len(time_values))
ax.set_ylim(0, 75)

plt.show()
plt.show()
